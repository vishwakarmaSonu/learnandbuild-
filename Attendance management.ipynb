# %%
teacher = {"rakesh":"S@1lo","mohit":"Mo@23j"}

# %%
student = {1001:['sonu','p'],1002:['mohan','a'],1003:['rohan','p']}

# %%
def signup():
    user_name = input("enter user name")
    password = getpass.getpass("enter password")
    3
    lower =0;
    upper =0
    digit =0
    special =0
    for i in password:
        if i.isupper():
            upper += 1
        elif i.islower():
            lower += 1
        elif i.isdigit():
            digit += 1
        elif not (i.isidentifier()):
            
            special += 1
            
    if lower >= 1 and upper >= 1 and digit >= 1 and special >= 1:
        teacher[user_name] =password
        print("Signup successfull......\n thank you")
    else:
        print("please try again.. password should be one Uppercase, one Lowercase,one digit and one special charater")
        signup()

# %%
def view():
    print("student detail...")
    return student

# %%
def take():
    print("following are the information of student one by one you can see just take attendance of the student")
    print("For persent press small 'p' and absent small 'a' ")
    for i in student:
        print("Take the attendance of this student ID.",i)
        at = input("take attendance")
        student[i][1] = at
    print("thank you ")

# %%
def add():
    print("enter the student name \n At the begining student is present")
    name = input()
    student[list(student.keys())[-1]+1] = [name,'p']
    print("data is added.")

# %%
def delete():
    print("enter Id of student ")
    id = int(input())
    if(id in student.keys()):
        
        del student[id]
        print("thank you this id ",id ,"is deleted")
    else:
        print("This Id is not present ")
        delete()

# %%
def update():
    print("enter the Student ID")
    print("name and attendance are updated")
    ids = int(input())
    nam = input("enter new name here")
    at = input("take attendance")
    student[ids] =[nam,at]

# %%
def login():
    user_name= input("enter user name")
    password = input("enter password")
    
    if user_name in teacher.keys() and password == teacher[user_name]:
            while True:
                print("press 1 for view detail \n press 2 for take attendence\n press 3 for add student \n press 4 for delete the student \n press 5 for updations\n press 6 for logout")
            
                
                stu = int(input())
                if(stu == 1):
                    print(view())
                elif(stu ==2):
                    take()
                elif(stu == 3):
                    add()
                elif(stu == 4):
                    delete()
                elif(stu == 5):
                    update()
                else:
                    print("Logout.....")
                    break
            
    else:
        print("Try again!")

# %%
def atten():
    while True: 
        print("Attendance Management System Python Project Documentation")
        print("If you have user name and Teacher ID then press 1 ")
        print("press 2 for registration")
        print("press 3 for exit")
        att = int(input())

        if(att == 1):
            login()
        elif(att == 2):
            signup()
        else:
            break
atten()
# Out:
# Attendance Management System Python Project Documentation
# If you have user name and Teacher ID then press 1
# press 2 for registration
# press 3 for exit
# 1
# enter user namerakesh
# enter passwordS@1lo
# press 1 for view detail
#  press 2 for take attendence
#  press 3 for add student
#  press 4 for delete the student
#  press 5 for updations
#  press 6 for logout
# 1
# student detail...
# {1001: ['sonu', 'p'], 1002: ['mohan', 'a'], 1003: ['rohan', 'p']}
# press 1 for view detail
#  press 2 for take attendence
#  press 3 for add student
#  press 4 for delete the student
#  press 5 for updations
#  press 6 for logout
# 2
# following are the information of student one by one you can see just take attendance of the student
# For persent press small 'p' and absent small 'a'
# Take the attendance of this student ID. 1001
# take attendancea
# Take the attendance of this student ID. 1002
# take attendancep
# Take the attendance of this student ID. 1003
# take attendancea
# thank you
# ...
